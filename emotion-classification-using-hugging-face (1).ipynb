# %%
import pandas as pd
from transformers import pipeline

import warnings
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv("/kaggle/input/emotion-classification-nlp/emotion-labels-train.csv")

# %%
classifier=pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
txt =df['text'][200]
txt
# Out:
# '@Nikhilv95 @LydiajaneF I wish, I really, truly wish, that I had just a modicum of your banter. #hilarious'

# %%
label_test =df['label'][200]
label_test
# Out:
# 'joy'

# %%
labels =list(set(df['label']))
labels
# Out:
# ['joy', 'fear', 'sadness', 'anger']

# %%
classifier(txt , labels)
# Out:
# {'sequence': '@Nikhilv95 @LydiajaneF I wish, I really, truly wish, that I had just a modicum of your banter. #hilarious',
#  'labels': ['joy', 'anger', 'sadness', 'fear'],
#  'scores': [0.6200655698776245,
#   0.17140693962574005,
#   0.10646932572126389,
#   0.10205817967653275]}
